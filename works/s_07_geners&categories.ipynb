# %%
pip install requests

# %%
pip install pandas

# %%
import requests
import pandas as pd


client_id = "45da58455f7f46d5b30b0b8a117fa452"
client_secret = "7dd2efbeaecd4fd08136e682f7610f48"

# 獲取 access_token
def get_access_token():
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials"
    }
    response = requests.post(url, headers=headers, data=data, auth=(client_id, client_secret))

    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Failed to obtain access token. Status Code: {response.status_code}, Response: {response.text}")
        return None


# 查詢 genres
def get_genres(access_token):
    url = "https://api.spotify.com/v1/recommendations/available-genre-seeds"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    response = requests.get(url, headers=headers)

    # 檢查status_code
    if response.status_code == 200:
        genres = response.json()
        return genres["genres"]

    else:
        print(f"Failed to get available genres: {response.status_code}")
        return None

# 主程式
def main():
    access_token = get_access_token()

    if not access_token:
        return

    # 將查詢結果存入 DataFrame
    result_data = []
    
    try:
        genres_info = get_genres(access_token)

        if genres_info:
            result_data = [{"genre": genre} for genre in genres_info]
            df = pd.DataFrame(result_data)
        
            # 保存結果到 CSV
            result_csv_path = r"C:\Users\T14 Gen 3\Desktop\KKbox_Spotify_va13\genres.csv"
            df.to_csv(result_csv_path, index=False)
            print(f"Genres saved to {result_csv_path}")

        else:
            print("No genres info found.")
    
    except Exception as e:
        print(f"Error processing: {e}")


if __name__ == "__main__":
    main()
# Out:
# Genres saved to C:\Users\T14 Gen 3\Desktop\KKbox_Spotify_va13\genres.csv

# %%
import requests
import pandas as pd


client_id = "45da58455f7f46d5b30b0b8a117fa452"
client_secret = "7dd2efbeaecd4fd08136e682f7610f48"

# 獲取 access_token
def get_access_token():
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials"
    }
    response = requests.post(url, headers=headers, data=data, auth=(client_id, client_secret))

    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Failed to obtain access token. Status Code: {response.status_code}, Response: {response.text}")
        return None

# 查詢 categories
def get_categories(access_token, limit=50):
    url = "https://api.spotify.com/v1/browse/categories"

    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    category_info = []
    offset = 0

    while True:
        params = {
            "limit": limit,
            "offset": offset
        }

        response = requests.get(url, headers=headers)

        # 檢查回應
        if response.status_code == 200:
            data = response.json()
            categories = data.get('categories', {}).get('items', [])
            
            if not categories:
                break
        
            for category in categories:
                category_id = category.get("id")
                category_name = category.get("name")
                category_info.append({"id": category_id, "name": category_name})
            
            offset += limit  # 更新 取得下一页資料

        else:
            print(f"Failed to get categories: {response.status_code}")
            break

    return category_info
    
# 主程式
def main():
    access_token = get_access_token()

    if not access_token:
        return
    
    try:
        categories_info = get_categories(access_token)

        if categories_info:
            df = pd.DataFrame(categories_info)
        
            # 保存結果到 CSV
            result_csv_path = r"C:\Users\T14 Gen 3\Desktop\KKbox_Spotify_va13\categories_info.csv"
            df.to_csv(result_csv_path, index=False)
            print(f"categories_info saved to {result_csv_path}")

        else:
            print("No categories info found.")
    
    except Exception as e:
        print(f"Error processing: {e}")


if __name__ == "__main__":
    main()

# %%
import requests
import pandas as pd


client_id = "45da58455f7f46d5b30b0b8a117fa452"
client_secret = "7dd2efbeaecd4fd08136e682f7610f48"

# 獲取 access_token
def get_access_token():
    url = "https://accounts.spotify.com/api/token"
    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }
    data = {
        "grant_type": "client_credentials"
    }
    response = requests.post(url, headers=headers, data=data, auth=(client_id, client_secret))

    if response.status_code == 200:
        return response.json().get('access_token')
    else:
        print(f"Failed to obtain access token. Status Code: {response.status_code}, Response: {response.text}")
        return None

# 查詢 categories
def get_categories(access_token, limit=50):
    url = "https://api.spotify.com/v1/browse/categories"
    headers = {
        "Authorization": f"Bearer {access_token}"
    }

    category_info = []
    offset = 0

    while True:
        params = {
            "limit": limit,
            "offset": offset
        }

        response = requests.get(url, headers=headers, params=params)

        # 檢查回應
        if response.status_code == 200:
            data = response.json()
            categories = data.get('categories', {}).get('items', [])
            
            if not categories:
                break
        
            for category in categories:
                category_id = category.get("id")
                category_name = category.get("name")
                category_info.append({"id": category_id, "name": category_name})
            
            offset += limit  # 更新 取得下一页資料

        else:
            print(f"Failed to get categories: {response.status_code}")
            break

    return category_info
    
# 主程式
def main():
    access_token = get_access_token()

    if not access_token:
        return
    
    try:
        categories_info = get_categories(access_token)

        if categories_info:
            df = pd.DataFrame(categories_info)
        
            # 保存結果到 CSV
            result_csv_path = r"C:\Users\T14 Gen 3\Desktop\KKbox_Spotify_va13\categories_info.csv"
            df.to_csv(result_csv_path, index=False)
            print(f"Categories info saved to {result_csv_path}")

        else:
            print("No categories info found.")
    
    except Exception as e:
        print(f"Error processing: {e}")


if __name__ == "__main__":
    main()
# Out:
# Categories info saved to C:\Users\T14 Gen 3\Desktop\KKbox_Spotify_va13\categories_info.csv
